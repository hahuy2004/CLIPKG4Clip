# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install torch==2.6.0 torchvision==0.21.0 torchaudio==2.6.0 --index-url https://download.pytorch.org/whl/cu126
# !pip install pyg_lib torch_scatter torch_sparse torch_cluster torch_spline_conv -f https://data.pyg.org/whl/torch-2.6.0+cu126.html
# !pip install torch_geometric sparse
# !pip install pycocoevalcap h5py tensorboardX boto3 requests pandas tqdm nltk ftfy open_clip_torch transformers
# !pip install stanfordcorenlp
# Out:
# Collecting torch_geometric
#   Downloading torch_geometric-2.7.0-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 1.9 MB/s eta 0:00:00
# Collecting sparse
#   Downloading sparse-0.17.0-py2.py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (3.13.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (2025.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (2.0.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (3.2.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (3.6.0)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.12/dist-packages (from sparse) (0.60.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.49->sparse) (0.43.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (1.22.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch_geometric) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->torch_geometric) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->torch_geometric) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->torch_geometric) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->torch_geometric) (2025.11.12)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from aiosignal>=1.4.0->aiohttp->torch_geometric) (4.15.0)
# Downloading torch_geometric-2.7.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 18.4 MB/s eta 0:00:00
# Downloading sparse-0.17.0-py2.py3-none-any.whl (259 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.4/259.4 kB 10.5 MB/s eta 0:00:00
# Installing collected packages: sparse, torch_geometric
# Successfully installed sparse-0.17.0 torch_geometric-2.7.0
# Collecting pycocoevalcap
#   Downloading pycocoevalcap-1.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (3.15.1)
# Collecting tensorboardX
#   Downloading tensorboardx-2.6.4-py3-none-any.whl.metadata (6.2 kB)
# Collecting boto3
#   Downloading boto3-1.42.7-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Collecting ftfy
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting open_clip_torch
#   Downloading open_clip_torch-3.2.0-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.3)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from pycocoevalcap) (2.0.10)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.12/dist-packages (from h5py) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorboardX) (25.0)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.12/dist-packages (from tensorboardX) (5.29.5)
# Collecting botocore<1.43.0,>=1.42.7 (from boto3)
#   Downloading botocore-1.42.7-py3-none-any.whl.metadata (5.9 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.17.0,>=0.16.0 (from boto3)
#   Downloading s3transfer-0.16.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.11.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2025.11.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ftfy) (0.2.14)
# Requirement already satisfied: torch>=2.0 in /usr/local/lib/python3.12/dist-packages (from open_clip_torch) (2.9.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from open_clip_torch) (0.24.0+cu126)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.12/dist-packages (from open_clip_torch) (0.36.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from open_clip_torch) (0.7.0)
# Requirement already satisfied: timm>=1.0.17 in /usr/local/lib/python3.12/dist-packages (from open_clip_torch) (1.0.22)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->open_clip_torch) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->open_clip_torch) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->open_clip_torch) (1.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open_clip_torch) (3.5.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->open_clip_torch) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0->open_clip_torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0->open_clip_torch) (3.0.3)
# Downloading pycocoevalcap-1.2-py3-none-any.whl (104.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 MB 7.6 MB/s eta 0:00:00
# Downloading tensorboardx-2.6.4-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 4.0 MB/s eta 0:00:00
# Downloading boto3-1.42.7-py3-none-any.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 8.0 MB/s eta 0:00:00
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 1.9 MB/s eta 0:00:00
# Downloading open_clip_torch-3.2.0-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 36.2 MB/s eta 0:00:00
# Downloading botocore-1.42.7-py3-none-any.whl (14.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.5/14.5 MB 52.6 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.16.0-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 2.6 MB/s eta 0:00:00
# Installing collected packages: tensorboardX, jmespath, ftfy, pycocoevalcap, botocore, s3transfer, boto3, open_clip_torch
# Successfully installed boto3-1.42.7 botocore-1.42.7 ftfy-6.3.1 jmespath-1.0.1 open_clip_torch-3.2.0 pycocoevalcap-1.2 s3transfer-0.16.0 tensorboardX-2.6.4
# Collecting stanfordcorenlp
#   Downloading stanfordcorenlp-3.9.1.1-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from stanfordcorenlp) (5.9.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from stanfordcorenlp) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->stanfordcorenlp) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->stanfordcorenlp) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->stanfordcorenlp) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->stanfordcorenlp) (2025.11.12)
# Downloading stanfordcorenlp-3.9.1.1-py2.py3-none-any.whl (5.7 kB)
# Installing collected packages: stanfordcorenlp
# Successfully installed stanfordcorenlp-3.9.1.1

# %%
import nltk
nltk.download('stopwords')
nltk.download('words')

import json
from tqdm import tqdm
from stanfordcorenlp import StanfordCoreNLP
import re
import string
import pandas as pd
import json
from nltk.corpus import stopwords
from nltk.corpus import words
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.

# %%
# !wget http://nlp.stanford.edu/software/stanford-corenlp-4.5.4.zip
# !unzip stanford-corenlp-4.5.4.zip -d /content/
print("Stanford CoreNLP downloaded and extracted.")

# %%
import os

# đổi working directory
os.chdir("/content/drive/MyDrive/0_Note_KLTN/Test_code/AKG-sv/KG")
print("Thư mục hiện tại:", os.getcwd())
# Out:
# Thư mục hiện tại: /content/drive/MyDrive/0_Note_KLTN/Test_code/AKG-sv/KG

# %% [markdown]
# ## Get Sentences

# %%
# dataset = 'msvd'
dataset = 'msrvtt'

def msvd_load_captions(caption_fpath):
    df = pd.read_csv(caption_fpath)
    df = df[df['Language'] == 'English']
    df = df[pd.notnull(df['Description'])]
    captions = df['Description'].values
    return captions

if dataset == 'msvd':
    cnt = 0
    train_id_path = '../dataset/MSVD/metadata/train.list'
    train_sentence_path = '../dataset/MSVD/metadata/train.csv'
    sentence_path = '../dataset/MSVD/metadata/msvd_sentence.txt'
    w = open(sentence_path, 'w')
    sentence = msvd_load_captions(train_sentence_path)
    print(sentence.size)
    for i in range(sentence.size):
        w.writelines(sentence[i])
        w.write('\n')
        cnt += 1
    w.close()
    print(cnt)

if dataset == 'msrvtt':
    file_path = '../dataset/MSRVTT/metadata/train.json'
    sentence_path = '../dataset/MSRVTT/metadata/msrvtt_sentence.txt'
    list1 = []
    cnt = 0

    with open(file_path, 'r') as f:
        load_data = json.load(f)
        f.close()
    w = open(sentence_path, 'w')
    # print(load_data, type(load_data))
    for i in load_data.keys():
        list1.append(load_data[i])
    for j in range(len(list1)):
        for key in list1[j]:
            w.writelines(list1[j][key])
            w.write('\n')
            cnt += 1
            print(list1[j][key])
    w.close()
    print(cnt)
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# a woman gets her hair extensions
# a woman is getting a haircut
# a woman is getting a haircut
# a woman is getting extensions in her hair while another girl talks about it
# a woman styles another woman s hair
# females giving a hair styling tutorial
# girl showing how to do hair
# one woman is getting extensions added to her hair by a beautician and another woman talks about it
# people get their hair done and get extensions put in
# this is a video of making hair
# two girls add hair extensions to a third
# woman has her hair cut and highlighted
# two girls add hair extensions to a third
# girl showing how to do hair
# one woman is getting extensions added to her hair by a beautician and another woman talks about it
# a girl is getting extensions put into her hair
# a girl is having hair extensions put in
# a person gets a haircut
# a stylist puts extensions into a woman s hair
# there is a male voice talking about animal head transplants while there are pictures of mice
# various scenes of mice as a man talks about different facts about them
# a discussion on animal transplants
# a person is holding a gummy bear
# a buch of rats are nesting forming a rat king
# a discussion on animal transplants
# a man discusses medical research regarding transplants
# a man discusses mice as laboratory test animals
# a man is discussing transplants on animals
# a man talking about animal transplants
# a man talking about transplants
# a man talks about a mouse head transplant
# a man talks about head transplants
# a man talks about successful animal transplants
# a mouse is shown
# a person is holding a gummy bear
# different pictures of mice are shown and talked about
# guy speaking about dead rats
# pictures of mice all bunched up together
# the history of head transplants is described
# a man making a filter
# a man preforming a party trick
# a man puts a paper towl inside a plastic bottle
# a man with a cup of ice
# a person inserting a paper towel into a 2 l bottle that has the bottom cut off
# a person stuffing a cloth inside of a plastic tube
# a soda bottle used for something else is shown
# man explaining and performing an experiment
# man showing how to make a homemade tool
# someone is showing some experiment s with a bottle and tissue paper
# a person stuffing a cloth inside of a plastic tube
# a man preforming a party trick
# a man describing how to make a filter out of a bottle and tissue
# a man does an experiment
# a man gives directions to make a homemade filter
# a man is making a water filter from a used bottle
# a man is putting a napkin in a soda bottle
# a man is putting on a cloth in a glass
# a man is showing how to use a bottle as a filter
# a man is teaching how to make something
# two men are dancing together
# two men in black and white shirts break dance
# two people are dancing in a dance room
# two people are dancing to a rap song
# two people are dancing to a song
# two people dancing together
# two people showing off their awesome dance skills
# people are dancing to a song
# a man and a woman are dancing in a room
# a man and a woman are dancing together
# a man and a woman are reinacting a popular song
# a man and woman dance together in sync
# a man is dancing
# a man is singing
# girls and guys are singing and dancing
# people are dancing to a song
# two asian people dance to a hip-hop song
# two asians show off their nae nae dance
# two men are dancing to music
# two men are dancing to r&b
# someone is filming a very large tornado that has touched down
# the car drives on the street near the hurricane
# a large hurricaine is slowly moving across a flat landscape there is lightning and a truck driving on a road
# a car and truck drive past a tornado in the distance which is moving steadily to the right
# a very large tornado quickly moves across an area of farmland and buildings
# a devastating view of a twister travelling across the area at a long distance
# a massive tornado passing over a farm in a flat area
# a large tornado funnel cloud sweeps across farmland next to roadside near homes
# storm chasers get close to a deadly tornado sweeping near homes
# stormchasers film a gigantic tornado in the distance
# fast coming of whirling hurricane gaining acceleration and may hit the place at any moment
# the trucks and the cars are passsing in the road by the mean time a hurricane is coming nearer and the huge sound is coming as it proceeds to wards it
# a tornado and a thunderstorm are looming in the background
# the storm is coming very fastly in the land near the highway the cars are passing in that highway
# a huge tornado spins through the sky as lightning flashes
# a car is gone very fast and it followed by a long vehicle gone
# there is a car moving on the road under the clouded sky
# a giant tornado sweeps through the country side and moves towards a barn as a semi truck goes in the other direction on the highway
# a hurricane rolls across an open field as lighting flashes in the background
# a video clip of a huge tornado that caused heavy damage to a small country side in america
# a geyser is steaming
# a hot spring
# a hot vapour from a water
# a video of a hot spring
# an aerial view of  landscape
# an exploration of smoking volcanic landscape
# looks like a volcanic or very hot spring area
# rocks are there in forest
# steam is rising from natural hot springs
# steam rising from hot water in a spring
# there are different views of rocks and water
# there is a hot spring
# there is an hot surface recording going on
# this is a view from atop a crater
# this video is about volcanoes
# video of hot springs between sand dunes
# water vapors out of a small pond
# video of hot springs between sand dunes
# an exploration of smoking volcanic landscape
# a geyser is steaming
# a person is pouring coffee from the little kettle
# a person is pouring coffee into a small cup and serving some snacks into a small plate
# a person is pouring coffee
# a person is pouring tea into a tiny mug and stacking tiny pancakes onto a tiny plate
# a person places some food on a plate
# a person prepares for tea time
# a person serving a tea in a cup
# a teacup set is examined
# a woman is placing food and drink onto a miniature tea set
# a woman is pouring tea
# a woman pours a tiny cup of tea and prepares tiny pancakes
# a woman pours tea into a cup
# it is about some food
# pouring coffee in a cup and snacks in a plate
# scene from a cooking show
# someone demonstrating the use of a doll sized tea set with dishes
# someone is pouring tea and putting food on a plate
# a woman pours a tiny cup of tea and prepares tiny pancakes
# it is about some food
# a woman pours a tiny cup of tea and prepares tiny pancakes
# a boy is playing minecraft
# a boy is playing minecraft
# a child explains minecraft
# a dog runs down the street
# a kid comments over his gameplay of minecraft
# a little boy is streaming himself playing minecraft
# a little boy showing an amusement park built in minecraft
# a male child is playing the video game minecraft
# a person describing video game play
# gameplay footage of minecraft
# it is about a cartoon film
# kid playing minecraft and talking about it
# scene from a video game
# searching the entrance to come out
# someone is walking around in minecraft
# the little boy is looking inside a game
# this is a child playing a computer game
# a person describing video game play
# it is about a cartoon film
# someone is walking around in minecraft
# a woman wears a top knot in her hair a low cut gray top and a large turquoise necklace
# there is a woman showing a finger sign
# a black lady with big mamma stands with awesome make up
# a lady wearing blue color necklass is standing
# two lady picture showed
# a woman wears her black hair in curves on top of her head a gold chain with turquoise pendants a white scarf draped around her neck
# a black woman shows off her necklace and hair
# a woman show how to wear outfit different ways
# a lady model giving poses to camera in home
# an exploration of something about a lady model giving pose to camera
# women showing two fingers looking into mirror
# a woman showing off her outfit and well done makeup before she heads out for the night
# a woman looks into the camera and poses while music plays
# a woman looks into the camera and poses while music plays
# a women is posing in an attempt to show off her outfits
# african woman with nice make up is talking in front of camera
# woman in colorful clothes is recording herself with camera
# sexy brunette in glass getting a selfie on camera
# a catchy tune plays while a black woman prepares for a night out
# a black woman with a vest is inside
# a mice walking on a wheel runs away from it
# a rat sitting in a wheel and rotating
# cool music and a ladies voice while a hampster plays
# women describes a hamster cage setup while video of a hamster plays
# halloween decor in a haster s cage a hamster on a purple wheel spinning
# a small glass pumpkin sitting next to a small container of dip followed by a hamster in a wheel
# a woman is in the beginning stages of describing decorating for halloween
# a woman talks about ammonia stains on hamsters comfort wheel
# a girl describes the items she has in her hamster s cage
# a spider climbs down the screen and a rodent runs in a wheel
# a person showing halloween craft with the wheel for the hampster
# a person showing halloween theme for the hamster
# a small halloween pumpking toy a hampster rides on a wheel
# there is a mouse walking on the floor
# a woman showing her hamster and his accessories in it s cage
# different article are placed and a mouse moves out of a wheel
# a female speaker gives the dimensions of her pet hamster s wheel
# someone is talking about making a cage for their rodent themed in halloween decor
# a spider comes down over a pumpkin and a hamster runs in a purple wheel
# a mice sitting in the wheel and goes out of it
# a lady with blonde hair and her band are singing
# a beautiful women is singing while others watch
# a beautiful women is singing while others watch
# there is a woman is singing a song with sweet voice
# there is a woman is singing a trendy song
# there is a woman with brown hair is singing a song
# a female group is performing on stage while playing instruments
# a girl with long blonde hair is singing her hit song
# a girl sings on stage a song to a boy she likes
# a lady is singing a song\
# a lady is singing on the stage
# a girl sings in the mic and musicians around them to make music
# avril lavene singing a song on a stage
# a lady singing the song with her group on stage
# a young woman is singing a haunting melody
# a music video by avaril levine in a hoody
# a woman singing in a mic with people in background playing instruments
# a girl with blonde is singing with a band behind her
# avril lavigne performs on stage in front of a band
# a long-haired blonde woman wearing a pink hoodie is singing into a microphone
# many girls wearing revealing clothing work on cars in an auto shop
# there is a woman in black is moving with a cycle
# woman in green pants and a white sleeveless top is singing while walking around in a auto mechanic garage filled with cars and women mechanics
# women sing and dance around a garage to a pop song
# woman with large ear rings and white dressing getting ready and sings in a car workshop
# a music video by the pop artist rihanna is being shown
# a lady is repairing a car and singing a son
# a lady is repairing a car and singing a son
# in the car factroy the model girl is ready start their job in very well
# women roll tires across a garage floor place tools on cars tuck a gray rag into their pants and work on automotive engines under raised hoods
# a modern car service station the young girls maintain its service with melody songs  it is welcomed all over the world
# a group of people at a reparepair shop as rhiana sings
# an african woman walks along some cars and sings a song
# rihanna music video inside a auto shop with lots of cars and tools with upbeat music in background
# several woman working on cars then one begins to sing
# the workshop scene where cars are repaired is mingled with dance and music
# a pretty young woman sings a song while standing by cars
# a music video shows a woman working on an old car
# a woman with green pants is standing near some cars
# some people are singing and dancing in a music video
# a kid gets hit in the face with a soccer ball
# a soccer ball was thrown into someone s face
# a soccer game is being played
# a soccer player is getting hit in the head with the soccer ball
# a soccer player throws a ball into another s head
# a soccer player throws the ball in and hits a person
# a video clip of soccer players set to music
# a video of a boy getting a ball thrown in his face
# comedic video of a soccer match outtake
# during a soccer match one of the players throws the ball at the face of another player twice the second time knocking them down
# girl gets hit with a ball
# music playing while a soccer game commences
# people are playing a soccer game
# player gettng hit twice in the head with a soccer ball
# soccer game with silly music
# some guys are playing in a ground
# some people are playing soccer
# a kid gets hit in the face with a soccer ball
# a soccer player is getting hit in the head with the soccer ball
# comedic video of a soccer match outtake
# woman is applying make up
# women are being made over to show different decades
# two women are changing their fashion styles simultaneously
# a woman shows off various hair styles
# a movie clip compares make up in north and south korea
# a video of a asian women getting different types of makeup dancing around
# a woman having make up applied
# a woman shows off various hair styles
# an asian woman getting different styles of hair and makeup
# people are doing hair and makeup of korea
# people are putting on makeup on two women
# people getting make overs
# side-by-side videos show the contrast between the women of north and south korea over time
# south korea and north korea makeup side by side
# the difference in a n korean vs korean woman s makeup is being shown
# the evolution of hairstyles in north vs south korea
# two women are changing their fashion styles simultaneously
# two women being made up in time lapsed video to music
# two women get their hair and makeup done
# two women having their makeup done
# a man is being helped into bed in his underwear by two men in suits
# a physio wearing black color suit white shirt and black neck tie is helping to a fighter who brought there after fight
# some men in suites carry another man to bed and then try and figure out what to do with him
# the man is highly intoxicated that he cannot be brought back to normal
# two men in suits lay a naked man down on top of his bed
# there is a black suit man is helping a man
# there is a black suit man is helping someone
# two men in suits help a man in underwear and socks get into his bed
# three suited men apprehend a man in his underwear
# two men are helping an exhausted men into bed and giving him a cool cloth for his head
# two men carrying a man dressed only in his underwear to his bed
# a drunk man is carried into a bedroom by men in suits
# a man without shirt and phant was taken into the room by three gentle men
#  in dark underpants is helped by two men in black suits into a room and onto a bed under two framed pictures of women
# multiple men in suits support a bare chested man through a door and to bed
# two men are dragging a dark-skinned man into a bed
# three men in suits help the drugged induced man to his bed
# two men are holding another man and putting him  on the bed
# two men are holding another man and putting him  on the bed
# a man is taking by other men in a room and place in his bed
# a video game character is driving a semi around the city
# a video game race car is driving down a road
# gameplay footage of someone playing a game
# someone giving demo for some game and talking about that
# someone playing a video game
# the big rig drives down the empty street
# a person playing a video game and commentating
# a semi truck is driving in a video game
# a cartoon diesel truck drives through a city
# a guy driving a military vehicle around while talking about it
# a man discusses and demonstrates a video game
# a man drives a truck in a video game and gives commentary
# a man explains the braking system of his semi on this video game
# a man is describing a vehicle in grand theft auto
# a man is playing gta 5
# a man playing a video game while giving commentary
# a person playing a video game and commentating
# a semi truck is driving in a video game
# a truck drives down the street in grand theft auto
# a truck is driving on a street
# a car driving down the interstate the cameraman showing lakes islands and road signs
# a car driving down the interstate the cameraman showing lakes islands and road signs
# person is travelling with car and recording the city
# a travel trip from roadgreen forest then tea table relief and next blue water
# views from inside a car of driving down a main highway by a lake
# a car drives along a bridge that passes over water
# a scenic drive from a car s point of view that depicts water and streets
# an island is being filmed outside by the sea
#  such as bodies of water and road signs are being filmed on what appears to be a road trip
# there is someone traveling in to the beach
# car driving and filming signs it sees cuts to a body of water then trees and finally to an island
# someone is taking a video from a running car capturing the ocean at the side and sign boards on the highway
# images of a car driving in florida over bridges by the water and of islands
# i see a lot of street signs and trees they look green
# in the driver of the car is enjoy their ride and watch the beauty of the sea
# in a travel tv the tourist centers are shown  green hill area a famous bridge is shown  the board instruct us no stop on bridge
# there is a vehicle driving on a highway over water
# a variety of roads are shown with water floods street signs and trees being under water
# a car driving on a road looking out onto the highway and at the ocean
# a car view of water a bridge and the road
# several beautiful goldfish in a fish tank that has white stones in the bottom and green plants
# two goldfish with long clear tails swim in an aquarium
# goldfish swim back and forth in a fish tank
# few gold with white mixed fish moving in the aquarium
# in a fish tank pure white and red and white fishes are swimming here and there  the air pump is working properly
# several fish swim around a tank through green plants and bubbles
# a group of color fishes swimming in the water
# small oddly colored gold fish swim around in a table top aquarium
# gold and silver colour angel fish with long tails looks like golden fish roaming here and there
# some fish swimming around in a fish tank looking very lonely
# in an aquarium with fewplanta five golden fishes are swimming
# fish swim in a bubbling fish tank with natural plants and other decorations
# a half dozen or so goldfish swim around a small indoor aquarium
# several goldfish with long fins swim in a tank the tank contains many fake grass plants
# a number of elegant gold fish are swimming around in a fish tank
# in a accurium some colorful fish are swimming with bubble of water
# in a colourful fish tank lot of fishes are running and its good to look
# many golden fishes are swimming inside the water container
# showing the movement of fish in a tank and their different movements and reactions
# some gold fish are swimming around in the water
# a crowd is chanting
# a crowd of people chanting
# a crowd protests in the streets of a city
# a funeral march of people
# a group of people are protesting on a street
# a huge crowd singing in the street
# a large crowd is transporting a body
# a mob is gathered for a funeral
# crowd carrying a dead body
# crowd of people protesting
# group of mourners carrying a man s body down a street
# hundreds of men marching in the street
# large people are gathered at one place
# many people are rioting
# people are taking dead body of a person accompanied by a huge  gathering
# people protesting in the city
# people rally in a large crowd
# video not loaded
# large people are gathered at one place
# a group of people are protesting on a street
# a video showing the various games of xbox live
# we can see some advertisement on the screen here
# there is something impressing matters goin on
# a game player discusses how to play the online game skyrim and other games
# a gamer discusses several games he has on his xbox gaming system
# there are different setting shown on the screen
# there are some basketball players practising basketball on court
# the business men analyise the new model car and the probability of their market
#  sleeping dogs xbox live
# skyrim snoopy titulos de a a z s sleeping dogs
# a gamer is browsing through his game list on xbox live
# a man is explain about a xbox live
# a purple background video with the names of the filmone of the name is snoopy
# a person is switching through the games on their xbox one screen
# some advertisement shown about the cartoon film
# player playing video game in xbox trying to get better car
# various games of xbox live shown into user account
# a person is browsing around on xbox live
# a person is browsing games on their game console
# someone is browsing around on their xbox system
# a man in a car driving down a road surrounded by trees
# there is a man in white dressing traveling in a car
# through a road flanked by trees a car is being driven by a man in white tshirt
# through a road in a jungle a man is driving a car
# two persons are travelling in a vehicle along the road
# a group of young men film themselves drive along an empty road stretch
#  with an oval face and facial hair forms a circle with his lips as he sits in the dark interior of a car driving down a country road by green trees
# men filming while they are driving on a winding road
# a camera shows the view from a car driving down a two-lane blacktop road and then reveals the driver s face
# people in a car are driving on a dirt road while talking
# guy wearing seat belt and driving car
# two men inside of a car going to a place
# two men in a car traveling down a country road to check on dogs
# car driving very fast on a country road and a shot of the driver
# a car goes on the road with a person
# a young man drives a vehicle down a road in the woods and appears to be searching for something
# a car drives down a country road through the woods
# a person is driving the car on the road around the green plains
# a guy with a white shirt is drivig a car out side
# a person is driving their car in a forest
# a group is singing a song
# a man is talking
# a woman talking to the president
# barack obama is talking on phone
# obama talking to friends on phone
# obama talks on a telephone
# obama talks on the phone
# president obama is speaking on the phone with somebody
# president obama is stuttering on the phone
# president obama is talking on the phone
# president obama speaking to someone on the telephone
# president obama talking on the phone
# president obama talks on the phone
# scene from a reality tv show
# the president is talking on the phone
#  president obama talking on phone
# united states president seems to be busy talking in phone
# president obama speaking to someone on the telephone
# president obama speaking to someone on the telephone
# obama talking to friends on phone
# a girl s game is shown
# a peppa pig game is being played
# a person is playing a video game
# a person is playing a video game
# a person playing a game designed for children
# a person playing a peppa pig video game
# a table with a pot on it
# cartoon clips in animations
# child plays pig game
# demonstration of a game or app with cartoon characters
# gameplay footage of someone playing a game
# playing a dress up video game with pigs
# someone is playing a computer game that contains pigs
# the display was very colorful
# there is a video game with someone selecting different pigs in a room
# demonstration of a game or app with cartoon characters
# a children s computer game is shown
# a frozen screenshot of cartoon pigs in a room
# a game based on peppa pig is being played
# a game is being played
# a man and woman are talking
# a man is in a phone booth
# a man is talking behind the wall
# a man is talking to a woan
# a tv show featuring two young men and a woman
# a video about doctor who
# a young man is talking to a woman
# dr who is talking to a woman
#  who talks to woman
# its a boy speaking with a firl
# man is talking to a woman
# man speaking to person in cage
# man talking to someone woman
# scene from a movie
# video of a man and a girl having a conversation
# a man and a woman talk as part of a scene from dr
# a boy talking in front of the camera
# a character gives a speech and the tardis shows up
# a male and female arguing with one another
# a man and a woman talk as part of a scene from dr
# a guy talking about a computer program
# a man begins to give a photoshop tutorial
# a man describing photo shop scripts
# a man doing a photoshop tuturial
# a man expling about photoshop
# a man initiating a tutorial on photoshopping
# a man is demonstrating how to use a computer program
# a man is talking about something
# a man is talking about something computer based
# a man talking about photo shop
# a man talks about a computer
# a man teaching photoshop
# a mans speaks to a camera in front of his computer
# a person giving a tutorial about photoshop
# a person is playing a video game
# a person is talking about photoshop
# a photoshop tutorial on action strips
# a person is playing a video game
# a man expling about photoshop
# a person giving a tutorial about photoshop
# a montage of sport s games highlights
# a professional hockey player playing hockey with music in the background
# a team playing hockey
# a video of random people and teams playing hockey
# different clips from hockey games with music in the background
# hockey players showing off their skills and tricks
# ice hockey is being played
# ice hockey sports vine clips
# ice skating hockey players hitting goals
# people are playing hockey
# some people are playing hockey
# teams skating playing hockey
# this is a set of hockey clips in a vine
# video from best of vine sports
# video of athletes performing amazing plays
# video from best of vine sports
# a hockey player is making a trick shot into a goal to score
# a hockey player is scoring a goal
# a hockey player scores a goal
# a hockey sequence is shown to music
# a blue colour camp was built near a river bank
# a beautiful location view for a camping spree with the flowing brook mountains and forest around you
# gorgeous mountain landscapes in either the summer or the fall
# an campaign sausage with a beautiful and incredible mountain view during the tour trip
# a tent is set up near stream in rugged mountain forested area
# there is a tent next to a creek in the middle of a beautiful forest
# a large tent near a water fall and river in a forest
# a river roars in the forest as the camera pans up the the mountains
# person is presenting the way of camping in the nature
# presentation of a camping in the mountain with trees
# a temperate high range area in the bliss of sunlight the natural stream flows
# a camping video is shown in which the scene display a river and mountain range view
# there is a beautiful place having mountains and rivers
# there is a waterfall flooding through the forest
# a wooded area with a lot of trees and bushes
# a campsite located next to a small waterfall is seen as a blue tent sits in the foreground
# camping in a wooded forest right beside a creek and mountains
# a peron filming their camping experience with views of a river and mountains
# tent next to running water and trees covering a mountainside
# water falling heavily from top of a hill
# a car crashes during a race
# a car drives off the race track and explodes
# a car goes off track and crashes
# a car in a motor race crashes violently into a barrier at the race track
# a clip showing an accident in a car race
# a nascar crash is shown
# a race car crashes into  a wall during a race
# a race car has crashed into the wall
# a race car is crashing
# a racecar driver gets into an accident
# a video about a serious accident during a race
# a video of a car race and one of the cars has a huge crash
# car crashing to the wall in race track
# cars are racing on a track
# footage of a crash during a large auto race
# race car gets into a serious wreck
# race cars are racing and one crashes
# some  sports cars are running and one is crashed
# a car goes off track and crashes
# a racecar driver gets into an accident
# a girl singing about safe sex
# a girl sings and impersonates katy perry
# a group of people are performing
# a man dressed as katy perry singing doing a parody video of dark horse
# a man dresses as a woman and does a parody of a katie perry song
# a man in a wig
# a music video spoof for a katy perry song
# a paradoy music video of a music video
# a parody music video for a song by katy perry
# a parody video of dark horse
# a person is singing
# a queen is ordering something
# a woman in a surreal environment sings about safe sex
# a woman is singing a song in different costumes
# a woman is singing
# a woman wears a bunch of costumes and sings
# people dressed in various costumes are singing along with a pop song
# a man in a wig
# a girl singing about safe sex
# a queen is ordering something
# special effects are used to make it seem like people are singing what they are saying
# the crowd is clapping their hands
# politiians speak at a summit
# a man is singing a song and others in a cabin are clapping
# a comical clip made out of a political convention
# a crowd of people are clapping to the beat
# a man is singing a song and others in a cabin are clapping
# a man is talking to a crowd that is clapping
# a man is talking
# a meeting in great britian s house of parliament set to a musical song
# a meeting of parliament is autotuned
# a mock video of people in the un
# a person is talking about something
# a politician is being mocked
# a song made from a compilation of news stories
# guy standing up talking and people clapping
# many people are clapping while a man is singing
# parliament members sayings are turned into music
# politicians appear to sing and clap in this auto tuned video
# politiians speak at a summit
# a video game being played capturing coins
# a video game character is flying through the air collecting coins
# a video game sequence is shown that has a dog running through a space-age hallway
# a video game streamer speaks as he plays a game
# a video game with diffrent eviroments being played
# footage of a video game being played
# its a animated video game
# jetpack joyride is played
# person plays a game where they can collect a lot of coins
# scenes from a sidescrolling video game
# someone is playing a game
# someone is playing a video game that runs across the screen
# someone is playing a video game
# someone is playing a video game
# someone playing a doctor who video game
# video game following creature getting coins
# a character collects coins as they run through the mission avoiding the electricity
# a person is chasing a dog in the video game
# a person is playing a video game
# a person is running a playthrough of a side scrolling game
# a woman on the cooking channel is showing some of the different ingredients she will be using for her recipe
# a  girl in blue color dress wearing cloth and vegetables  dishes inside kitchen to prepare to serve to eat displaying on screen
# a chef on food network displays very colorful vegetables
# a young woman arranges vegetables on a plate
# giada displays red tomatoes green asparagus zucchini and purple eggplant
# giada displays red tomatoes green asparagus zucchini and purple eggplant
# a lady is introducing some vegetables  to prepare
# a chef shows us the ingredients she will use including eggplant yellow squash and mushrooms
# a lady is with vegetables like tomatoes lady s finger brinjal etc in the kitchen
# the lady talks about the vegetables that are kept on the table
# vegetables are taken by aldy
# the woman is checking the different vegetables kept on the table in the kitchen
# a woman is talking about vegetables such as peppers and zucchini
# a slender woman in a white kitchen with two windows identifies the colorful and curved vegetables on her counter
# a famous tv chef describes the vegetables she will be using in a recipe
# a fully of fresh vegetavbles are placed in the kitchen where a lady is looking into it
# a woman holds an assortment of different vegetable including eggplant squash and asparagus
# a woman is describing red bell pepper japanese eggplant asparagus tips yellow squash crimini mushrooms and scallion
# a girl shows red peppers zucchini & yellow squash and mushrooms and scallions
# brunette woman is preparing the ingredients in the kitchen
# from a indoor stadium where an event of track huddles race for man is going on
# a group of athletes jump hurdles on the track
# a line of young athletes sprint down a track over hurdles
# eight people are running in hurdel jumping race in 5 jumping stages and reach the destination both side people are standing and watching and person in blue shirt takes photo and red color shirt wearing person stand near him
# track and field athletes run quickly around a track and over hurdles
# athletes are getting ready and start running for an event
# there are some athletes flying in to the track
# there is a athlete running hard for a victory
# a man narrates while people start running and jumping hurdles on an indoor track
# eight men are lined up in the starting blocks just before a hurdle race
# the athletes get set and start the run over hurdles and finish
# more players jumping the stick
# racers walk in a row across red track lanes outlined in white by photographers and a white travel banner
# sprinters having a race over hurdles at a track and field event
# several men race over hurdles in a short race
# its athlet game where many players started to run after hearing gun shot
# seven runners run a hurdle race on a red track
# group of sprint runners preparing to race and jumping over the barriers
# the players are on the line and starting to run
# a group of boys  running in race ground chasing each other audience watching  displaying on screen
# a young girl with dark layered hair glassess and braces is talking to the camera while wearing a lab coat and blue lanyard
# a woman in a white top introduces her topic of genetics
# a female doctor in a white lab coat introduces a program in which genetic engineering and its impact on our species will be discussed
# medical student explain about the revolution in  genetic and and bio technology
# the medical students talks about revolution in genetic and bio technology
# the medical talks about revolution in genetic and bio technology
# a young woman with dark hair and glasses and wearing a lab coat talks into the camera
# a woman in a white lab coat discusses the revolution in genetics and biotechnology
# a young asian woman talks about advancements in genetics and biotechnology
# a young asian woman talks about recent progressions in biotechnology
# a student of genetic and biotechnology shares her views of the subject and as to why she has selected it as her career
# a woman explaining about the eye and the care for the eye with an special tips
# a girl with black hair and a white shirt talks to the camera
# a girl in white  dress wearing  color cloth  standing  speaking discusing displaying on screen
# revolutions in biotechnology discussed by young lady wearing lab coat
# a young woman is talking about new discoveries in genetics and biotechnology and how it will affect us as a species
# asian lady in lab coat talking about genetics and eyes
# a woman in a white coat and glasses is speaking to the camera
# a female talks about genetic engineering in bio technology in the human species
# a female talks about genetic engineering in bio technology in the human species
# there is a work going on in the factory
# there are images of a plant where people are using a vacuum induction machine
# a company producing steel
# there are images of a plant where people are using a vacuum induction machine
# a company producing steel
# a fire is burning
# a large machine lifts a machine into the air
# a machine cuts molten hot bars
# a man discusses manufacturing
# a man is describing the melting process
# a man is talking about working with metal
# an explanation video on a smelting factory
# heavy metal melting and shaping
# inside a factory clips of how they do ingot castings
# large tell being melted in a factory
# men are working at a steel manufacturing plant
# someone is in a factory
# someone is melting a metal in a industry
# the melted went through several processes
# there are images of a plant where people are using a vacuum induction machine
# a city is being filmed
# a few shots of some interesting architecture
# a panning view of various ranch style buildings
# a panorama of a european street scene is shown
# a short clip showcasing the landscape and city of an older european village
# a view of town
# an overview of a beautiful city
# an overview of a city is shown
# architecture in a city on a sunny day
# old buildings in a city are shown
# panoramic video of an older city
# panoramic views of a city
# someone is showing some building and houses
# the buildings in the video
# the camera is panning across a european city
# the city and the environment are video taped
# this is a video of old apartments
# trees in front of houses
# an overview of a city is shown
# someone is showing some building and houses
# in a kitchen someone is cooking with a lot of fresh leafs
# there is a woman making a dish with some leaf s
# a woman chops tomatoes and tuna she adds them to a salad
# a person makes a salad on a dark counter in a white bowl using tuna fish
# some leaves are kept on the plate then tomato is cut and put on it then some seeds and some mixes
# hands add salad greens to a white plate cut cherry tomatoes in half slice the lower part of scallions
# a woman is narrating her preparation of a salad in a white bowl with beautiful red tomatoes and greens with tuna on top
# person standing cutting vegetables into a plate and giving instructions on how to do it
# a cooking tutorial video for a tuna salad with tomatoes and green onions
# a man explain and how is prepare the food
# a woman is cutting a vegetables for cooking
# a female or male making a salad that consists of lettuce and chicken
# a woman is explaining about the cooking of the food item
# person is mixing the vegetables on the white plate
# a  girl and a bowl cutting knife vegetables   mixing dish inside kitchen to prepare to serve to eat displaying on screen
# a british lady describes her salad as she makes it
# a woman prepares a salad with different vegetables
# a woman is making a salad with lettuce and tuna
# the salad is prepared with green leaves and tomato and cooked meat
# a woman arranges various vegetables onto a white plate
# a man fixes a machine
# a man is describing how to fix cooling lines
# a man is explaining how to repair a cooler
# a man is showing some pipes
# a mechanic is describing cooling lines and coolers
# a person fixing a car
# a person is explaining something
# a person is talking about the cooling line setup on a vehicle
# a person shows a close-up of a car engine
# a tutorial on home repair
# man talking of a car
# shooting about the firing place
# someone describing a dark room
# someone is showing tubes and talk about that
# someone is talking about automotive
# the person is shooting a video in the dark
# there are capturing video of pipe line
# a mechanic is describing cooling lines and coolers
# a man is explaining how to repair a cooler
# shooting about the firing place
# an old man wear blue shirt sits in the chair and talks to group of people
# a man talks to a group of people in a movie
# two men sit and talk by the window in the kitchen
# two men sit and talk by the window still on a desk
# an old man and many people sitting around table
# a meeting is going on  between a group of peoples in a confernce hall
# a light blue colored shirt wearing person being interviewed by group of five personsfour persons are black suite wearing gentlemen and one lady in light grey shirt
# one man siting on the chair is saying something to man opposite site to him this is situation like intervieww
# old black guy in suit is talking to the board members
# a man talks to a group of people in a movie
# morgan freeman talks to a group of people sitting at a large table
# a man is talking to someone inside of a house
# a hollywood movie scene showing  5 persons sitting on a table and talking with another man sitting in front
# there are many people sitting round the table and of of them is talking
# an actor is explaining something to a board of men
# a man addressing a group of people in a very hushy and serious tone about an incident
# a man conference talking to five person in office
# a african man is shown speaking to a group of 5 white people who are setting at a table
# a old guy talking to a group of people who are dressed in suits
# a man speaks to a group of people sitting at a table in a room
# a girl is talking about a wars show
# a lady is reporting some news
# a man playing video games
# a website advertising a place to gain knowledge and information
# a woman is giving information about a website
# a woman is talking about a website
# a woman reports about infowarscom and how they have over 60 movies and documentaries
# alex jones is speaking on infowars
# girl talking about news
# info wars logo screen
# lady explaining about a website
# pak team is playing circket
# person is telling the news
# woman and animation advertise infowars
# woman narrates information about a website
# alex jones is speaking on infowars
# lady explaining about a website
# person is telling the news
# a girl is talking about a wars show
# a woman is talking about a website
# a woman talks to a news show host on a finance show
# a man in a purple tie purple shirt and black suit is talking to a woman in a department store
# a old man in blue color   dress wearing cloth    speaking sitting   with other old lady in black dress inside shoping mall   displaying on screen
# a debate on consumer rights with the expert in consumer laws
# financial guru jim cramer interviews a female guest in a black suit while sitting in a retail store
# a guy with a beard is talking to a beautiful woman
# the man in the suit sit in the tall chair and talk to the woman
# the men is taking the interview at the book shop both are wear the black dress
# jim cramer is being interviewed by a news reporter while sitting in chairs
# a man is interviewing a woman in a retail store
# a man in a charcoal gray suit and purple shirt and purple tie is sitting in a stool in a cosmetics store conducting an interview with a woman who is also sitting in a stool wearing a dark gray business suit with a maroon blouse
# a girl interview the tv shows and choose
# jim cramer is interviewing a woman about plans for the future
# a man interviews a business ceo about the companies future
# women answering how hard she worked with her team
# women in formal wear answering a question from a guy
# a man is interviewing a women about her five year business plan
# a man with a purple tie conducts an interview with a woman
# a bald white man in a business suit is sitting on a chair in the middle of a store being interviewed
# a woman executive answers an interviewer s question about she formaulates her five year business plan
# a soldier is talking about his past experiences
# a soldier talks about urban combat with clips of training soldiers
# interview with a soldier about training
# man speaking concerning soldiers
# military men are performing urban operations
# soldiers are training in urban combat
# soldiers training for combat
# solider training in urban combat carrying guns in a building as a man sits in front of a screen explaining the dangers
# urban combat is a complex training
# a man is talking about military training
# a man discusses army training
# a man explaining some military tactics
# a group of soldiers walking up a set of stairs
# a man discusses army training
# a man explaining some military tactics
# a man is holding a gun
# a man is talking about army training
# a man is talking about military training
# a man talks about real world situations soldiers must go through
# a soilder sits and talks about combat
# a reporter is interviewed about the issues belgium has with radical islam
# two men discussing news about islamic extremist attacks in belgium
# a reporter in a black coat asks an expert in brussels why belgium seems to be a european hot-bed of islamic radicalism
# the man talks about belgium having a such a problem like radical islamic state
# a news spokesman talking to someone about the radicals  in paris  and asks  what is going on
# man is giving an interview on local tv show
# the two men talk to each other on a split screen
# a man reading news in the live news show
# a two men are talking in the television channel
# two men discuss why belgium has a problem with terrorism
# a news reporter talks to a man about the issues of a large country
# a man wearing a black tie talks while another man in a side screen listens
# live news report between paris and brussels two men discuss terrorism
# two men outside one man in with grey hair talks to a bald man in glasses
# two men talk both are wearing coats and are standing in front of buildings
# man in black jacket is talking for  the television
# person in black jacket is presenting the news on tv
# a old man  in black coat  color dress wearing cloth standing speaking with other man beside  still image photo beside displaying on screen
# an tv anchor asking the reporter from site regarding the problem in vatican
# two men are communicating to each other via a news program segment
# a cartoon wrestler takes a bow
# a cartoonish looking person standing in a boxing ring
# a character is in a wrestling ring
# a clip from a wrestling video game involving user-made characters
# a creature celebrates his victory
# a crowd is cheering loudly
# a person is playing a wrestling game
# a person on boxing stage
# a video game character is celebrating a wrestling victory
# a video game character is celebrating a wrestling win
# a video game is played
#  blue aqua-type wrestling character relishes in his victory
# an alien-like creature gloats to the audience of a boxing ring
# an animated character walking around inside a wrestling ring
# in a wrestling ring a wrestler is encouraging the crowd to get noisy
# spongebob wrestling match animation
# the boxing game ground
# the crowd cheers for a man in a wrestling ring
# video game character in the ring
# wrestling video game with live commentator
# wrestlers at match in grade school
# wrestling match on the ground
# wrestling match with dance music background
# wrestling matches at a school tournament
# a collection of highlight wrestling videos
# a montage of various clips from the same wrestling match
# a referee is judging two men wrestling
# a wrestler pushes another wrestler to the ground
# clips of wrestling matches
# diffrent groups of men wrestling in a gym
# epic music is played while two people wrestle
# people are wrestling at some sort of competition
# some people are playing wrestling
# the real game of spirit
# the wrestling match was a draw
# this a video compilation on kabadi wrestling
# two people are wrestling
# two people are wrestling
# two young men are wrestling
# various people are wrestling at matches
# a young girl sings a pop song and dances
# girl dancing and singing to animals
# girl is dancing and singing
# a woman is performing a song
# a female dressed in an unusual outfit singing
# a female is dancing
# a girl dances and sings
# a girl is dancing
# a girl is dancing around in a white room
# a girl is dancing to a trendy song
# a girl is dancing while singing in different outfits
# a girl is shown dancing to a song
# a girl is singing and dancing
# a little girl is a singing a song
# a music video with a young girl dancing and singing
# a small asian girl in a hat singing a rap song
# a woman is dancing
# a woman is performing a song
# a woman talking about relationships
# a young girl in a tiger hat is singing and dancing in front of a white background
# a woman s voice hosts while showing a clip of a morgan freeman movie
# a story about morgan freeman s best films and characters
# there is a old man talking to a stranger
# there is a suit man is talking to a old man
# a lady talking of something about two men
# morgan freeman has a heated exchange with a man in a suit
# a woman reviews the actor morgan freeman while we see clips of his movies
# a clip from the shawshank redemption starring morgan freeman shows the actor monologuing during a silent moment from a female narrator
# ...
# john green introduces the topic of california and texas statehood while sitting at a desk surrounded by a globe and chalkboard with pictures of california and texas
# the man sits in the black chair and talks at the table
# john green from crash course u history discussing how the united states aquired two of its largest states
# a male history teacher is teaching about how the united states acquired california and texas
# john green sits at a desk and begins to give a us history lesson
# a guy in tshirt hosting crash course us history
# a man in a blue and white striped shirt and glass talks in a prop classroom
# john green giving a humorous crash course of history discussing the us acquisition of california and texas
# a man is being seen riding on his horse into the distance
# man in blue shirt is sitting and talking about his study
# person in blue shirt is talking about his latest study
# a person in blue   color dress wearing cloth sitting  speaking beside globe and laptop beside on topic throwing laptop and still horse stitting man image displaying on screen
# john green talks about the united states aquiring texas and alaska
# a male person is teaching historical geography in a humorous manner
# a man rolls from right to left behind a desk with a computer and a globe on a stand rolls from left to right
# a guy in a striped shirt is sitting down and talking
# a man with glasses is speaking about something
# a man is giving a lecture
# a man is giving a presentation about the future
# a man is making a speech on on a stage with graphics showing up behind him
# a man is on stage talking about technology
# a man is standing on a stage and giving a speech
# a man is talking about something in stage
# a man is talking on stage
# a man is telling about some project
# a man speaks to an audience on stage
# a man standing on a stage giving a presentation with a digital screen playing content behind him
# a man talking about something
# a person is in front of a crowd at a conference and he is discussing   the fringe
# man on stage with snazzy graph background
# speaker talks about the future of civilization
# the speaker seemed well-educated
# a man is talking about something in stage
# a man gives a talk about how the future occurs
# a man giving a lecture about how the future happens  on the fringe
# a man giving a speech
# a man is giving a lecture on a stage
# a person fires a sniper rifle in a video game
# a person is explaining something
# a screen recording of people playing a shooting game
# an individual using a scope in a video game
# an shooting game shows in video game
# ia video game is played
# person playing a game
# someone is playing a first-person shooter video game
# someone is playing a video game
# someone is playing a video game
# someone is playing video game
# someone playing an online video game
# someone playing counterstrike
# the player shoots his gun
# a person fires a sniper rifle in a video game
# someone is playing video game
# a clip of someone playing a video game
# a first person shooter video game is being played
# a man is playing a shooting game
# a man narrates a video game
# a man in brown shirt is flipping over book and talking to a women
# some people are talking in different occasions
# there is a black suit man is talking with two people
# there is a man is talking with a friend
# there is a man is talking with a person
# a man flips through a science book while talking with a blonde woman about its contents
# a man talks about how much he likes pictures in a book he s looking at
# a clip of the hit movie interstellar features two actors a man and a woman talking to each other
# people are sitting on a set talking abou the new movie interstellar
# a person with brown shirt turns some book while a girl in green shirt speaks to him
# a scene from  interstellar  plays with a woman telling a man textbooks have been replaced with corrected versions
# a clip from the film interstellar where a man discusses altered textbooks on the apollo space missions with a woman
# man flips through a text book while talking to a school employee
# a man hands a book to a women in a blue sweater with blond hair in a bun
# a man sits across from a woman at a table and flips through a textbook while the woman explains that the textbooks have been corrected
# a man sits and looks at a book while a woman speaks to him
# a man is speaking to a woman in a blue shirt while skimming through a book
# man in brown shirt talking to a woman about a textbook that was corrected to lie to kids and it make the man upset
# a man flips through a book in which there are pictures
# guy in white tshirt and jacket talking to the sexy blonde
# a person is playing a computer online game
# a person is playing a video game
# a person is playing minecraft
# different level of video game
# man and woman play minecraft
# minecraft gameplay with a person narrating
# someone is looking in the inventory in minecraft
# someone is playing a video game
# someone playing a game of minecraft with a voiceover
# there people are playing an online game
# a large menu from the game minecraft
# minecraft gameplay with a person narrating
# a cartoon clip of video gaming
# a clip from a mine craft gameshowing their supplies
# a guy and a girl is playing minecraft together
# a guy playing a video game minecraft
# a large menu from the game minecraft
# a man and woman talk while the man shows his game-play of a video game
# a man is buying items on his video game
# a minecraft player opening a chest
# a bird is holding a creation made out of pigs
# a cartoon chicken is talking about trail mix and pigs
# a cartoon is talking to another cartoon
# a cartoon of two ducks talking to each other
# a cartoon with ducks talking
# a chicken holding something
# a pig is standing
# a small duck is talking to another duck
# a talking animated chicken shows off trail mix then a penguin shows up with a bunch of pigs loaded into a gun
# an animated chicken is talking to an animated penguin
# an animated duck is talking about something
# an animation of chicken and pigs
# animated chickens talk about humorous things
# cartoon birds are talking
# cartoon of two guys conversation
# cartoon with ducks about trail mix
# in a cartoon television show a duck is speaking with a large bird
# pigs are on top of each other
# animated chickens talk about humorous things
# in a cartoon television show a duck is speaking with a large bird
# this is a car review video
# video of a i-vtec engine
# a car engine is running
# a car s engine is running
# a car engine is running
# a car is being displayed
# a car s engine is running
# a cars hood is open
# a cars machinery is being displaced
# a close up of an engine running
# a engine is shown of a nice car
# a look under the hood of a car
# a motor in a red car is running
# a person is giving a walkthrough of a car
# a red car is parked
# a view of the new i-vtec engine of a honda while the engine is running
# exploration of a car engine
# honda vtec engine showcase
# someone is showing the engine of a car
# the hood of a car is raised and the engine is running
# a child singing an opera song on a talent show
# a contestant is judged on a tv show
# a female singer is performing
# a girl is singing a song on stage
# a girl is singing on stage for some judges
# a girl is singing on stage
# a girl sings on the stage
# a performer tries out on the voice tv show
# a red-haired girl auditions for the voice
# a woman is making the judges proud by singing
# a woman is singing on a television show
# a woman sings in spanish in a competition
# a young girl is singing on stage
# a young girl sings onstage with a band
# girl on stage singing a song
# girl singing time to say to goodbye on the voice
# scenes from a tv show
# a female singer is performing
# a young girl sings onstage with a band
# a young girl is singing on stage
# a compilation of sports highlights
# a hockey player skating on the ice
# a man scores a goal playing hockey
# a sports vine compilation is playing
# amazing sports plays caught on camera
# an ultimate vine compilation of hockey and basketball
# clips of hockey and basketball play as hip hop music plays for the ultimate vine compilations
# hockey player making a shot
# people are playing sports
# scenes from a sports game
# sketting on ice and football playing
# some guys are playing basketball in a basket ball court
# sports highlights are displayed
# sports vine compilation set to music
# they are playing skating
# video of athletes performing amazing plays
# vines of professional atheletes
# an ultimate vine compilation of hockey and basketball
# an ultimate vine compilation of hockey and basketball
# sketting on ice and football playing
# the car was a blaze
# there was a fire near the vehicle
# a person showing car
# a car catches fire after crashing
# a car catches fire after crashing
# a car is getting burned in a forest
# a car is on fire
# a car is on fire in the forest
# a car is on fire
# a car is on fire
# a car smoking and being on fire while a person in another car tries to call for help
# a car with a dummy in it is on fire
# a clip from a tv show is showing
# a clip taken from a video showing someone in a burning car
# a game is being played
# a person showing car
# a vehicle is on fire
# fire burning with a lot of smoke in front of the car
#  trapped inside a burning car
# man talking about man in car
# a cook allows the ingredients to cook in a saucepan after adding condiment and warns to be ready for the strong aroma of the peppers he is going to add
# a dish on the stove gets salt and pepper added to what ever is already in there
# a male teaches step by step how to cook as he adds condiments
# a man adds black pepper to his meal cooking on the stove
# a person is adding spices to vegetables in a pan on the stove
# a man is preparing special dish and sprinkling pepper powder on dish
# a chef puts some seasoning on the food in the pan
# a  man and a bowl mixing dish inside kitchen to prepare to serve to eat displaying on screen
# here animated characters are running doing something with machines in high speed
# a man cooks food in a silver pan on the stove
# a man is adding black pepper and sauteeing vegetables in a pan while discussing the next steps in a recipe he is preparing
# chef is showing how to pan-fry some chicken and mix in vegetables
# there is a man making a delesious dish in the kitchen
# a man cracks black pepper onto food in a hot sauce pan he then shakes the food and adds some hot peppers
# a man is adding cracked black peppercorns to a pan of hot food he is cooking
# someone is mixing the food item in the big pan in the kitchen
# a man is cooking in a silver pan on a stove top
# a man preparing some dish in his home and explaining it
# a chef adds black pepper to a silver pan of vegetables
# a chef adds black pepper to a small silver pan of vegetables
# batman and superman getting ready to fight
# batman standing in the rain threatening superman
# scene from superman vs batman movie
# scenes from batman vs superman
# some one is from a sky and landing in a ground while raining
# superman and batman are in the rain
# superman flies down from the sky
# superman jumps down to the ground in front of batman on a rainy night
# this is a clip from the superman vs batman movie
# two superhero characters meet in the rain
# superman and batman are in the rain
# a man is jumping from a building to the ground
# a clip from a movie with batman and superman
# a commercial for the new superman movie
# a man is jumping from a building to the ground
# a movie scene is going on of superman
# a preview of the movie superman
# a promo for batman vs superman with the characters silhouettes is playing
# a trailer for superman vs batman batman standing and super floating then slamming into the ground
# a video of batman and superman
# a girl and a couple of guys were climbing a rock of mountain
# a group of people are climbing a cinder cone
# a group of people rock climbing
# a man and boy are hiking
# a woman show the mountain and guys are walk on mountain
# many people are travelling
# people are climbing
# people are climbing a mountain
# people hiking up the side of a cliff
# person hiking a mountain
# several people climbing a mountain
# six people are going on exploration
# some people climbing on the mount
# some people hike to the top of a mountain
# some people hiking up a mountain
# young people are trekking on the hill
# some people climbing on the mount
# some people climbing on the mount
# person hiking a mountain
# some people hiking up a mountain
# a boy falls down and then is seen sleeping in a corner
# a boy in a cartoon play
# a boy is touching his head
# a cartoon about a boy
# a cartoon animation related to the game minecraft
# a cartoon boy is in a cave
# a cartoon character talking about voices in his head
# a cartoon figure sees a ghost
# a cartoon is crying
# a cartoon man is falling on the ground
# a cartoon of a man being haunted by a ghost
# a cartoon of minecraft
# a man is lying down
# an animated man is looking at something and falling down
# animation of character in solitude and his monologue
# cartoons are walking around
# the animated character had socks on his hands
# the cartoon character is talking to himself
# this is an animated cartoon video
# a cartoon figure sees a ghost
# two woman in a kitchen preparing a dish talking while one is pouring honey in the other ones mouth
# two women with their cleavage showing play with food in a kitchen
# a  two girls red and blue color dress pouring honey into mouth inside kitchen  a bowl  spoon mixing dish inside kitchen to prepare to serve to eat displaying on screen
# a two girls in blue and pink dress and a  bowl  spoon mixing dish inside kitchen to prepare to serve to eat opening mouth and pouring honey displaying on screen
# a woman is pouring agave-syrup into the mouth of another woman
# pretty young women talk in the kitchen where they re mixing food
# the two women add ingredients to the bowl while they prepare the food
# some women are inside of a kitchen
# a woman in a low cut red dress stands in a kitchen and pours honey into the mouth of another woman in a low cut blue dress
# a hot woman making a dish in the kitchen
# two woman in summer dresses making a sweet dish using agave
# the woman place the ingredients in the clear bowl
# two woman one with red dress another with blue dress preparing some cooking
# the tv programm for a celebrity cooking time
# woman in a dress squirts honey into another woman s mouth in a kitchen
# women in red dress pouring honey into another women s mouth in kitchen
# two women with lots of clevage talk about a recipe they are trying to make and squirt stuff in each others moouths
# two women in blue and red dresses cooking together as one woman feeds another woman honey
# two pretty girls talk while the one girl mixes something with honey in a bowl
# two women make a food dish together and the one girl puts honey in the other girls mouth
# a car engine is shown
# a guy explains how he works on a car
# a guy talks about leaning back the radiation
# a jeep has its hood open
# a man explaining a car repair
# a man explaining how to fix a car
# a man inspecting and explaining his car
# a man is describing the installation of a supercooler on a car
# a man is working on a jeep
# a man is working on his car s radiator
# a man works on a car engine
# a mechanic discusses installing a super cooler
# guy working on his car
# it is the machine accessories of installation
# man working on his jeep s radiator
# some machine shown in the picture
# someone giving details of modification of car accessory
# this is a car review video
# a jeep has its hood open
# a mechanic discusses installing a super cooler
# couple out in the forest kissing
# man kissing a woman
# this is a video from a movie scene
# two people are kissing
# two people are kissing each other
# two teenagers are making love
# two people are kissing each other
# a young couple softly kissing
# a couple kissing outside
# a guy and a girl kiss
# a man and a girl are kissing
# a man and a woman kissing outside
# a man and woman kiss each other
# a man and woman kiss
# a man is kissing a woman
# a man kisses a woman in a forest
# a man kisses the woman
# a man slowly kisses a woman on the lips
# a young couple softly kissing
# asian girl and boy kiss
# 130260

# %% [markdown]
# ##  Extract triples from sentences using Standford NLP

# %%
nlp = StanfordCoreNLP('/content/stanford-corenlp-4.5.4', lang='en')

dataset = 'msrvtt'
# dataset = 'msvd'

if dataset == 'msvd':
    sentence_path = '../dataset/MSVD/metadata/msvd_sentence.txt'
else:
    sentence_path = '../dataset/MSRVTT/metadata/msrvtt_sentence.txt'

entity_rel_path = f"{dataset}_entity_total.txt" # Output to current working directory with clearer name
log_path = 'error_log.txt'

f = open(sentence_path, 'r')
w = open(entity_rel_path, 'w')
log = open(log_path, 'w')
lines = f.readlines()
cnt = 0
num_rel = 0

for line in tqdm(lines):
    sentence = line.strip()
    try:
        output = nlp.annotate(sentence, properties={
            "annotators": "tokenize,lemma,ssplit,pos,depparse,natlog,openie",
            "outputFormat": "json",
            'openie.triple.strict': 'true',
            'openie.max_entailments_per_clause': '1'
        })

        data = json.loads(output)
        for i in range(len(data['sentences'])):
            result = [data["sentences"][i]["openie"]]
            lemmas = data["sentences"][i]["tokens"]
            cnt += 1

            for g in result:
                for rel in g:
                    subj_start, subj_end = rel['subjectSpan']
                    obj_start, obj_end = rel['objectSpan']
                    rel_start, rel_end = rel['relationSpan']

                    if max(subj_end, obj_end, rel_end) > len(lemmas):
                        log.write(f"[Warning] Span out of range at sentence {cnt}: {sentence}\n")
                        continue

                    # Sử dụng join thay vì nối chuỗi ngược
                    l_subject = ' '.join([token['lemma'] for token in lemmas[subj_start:subj_end]])
                    l_object = ' '.join([token['lemma'] for token in lemmas[obj_start:obj_end]])
                    # l_relation = ' '.join([token['lemma'] for token in lemmas[rel_start:rel_end]])

                    subj_tokens = [
                        token['lemma'] for token in lemmas[subj_start:subj_end]
                        if token['pos'].startswith('NN')
                    ]
                    l_subject = ' '.join(subj_tokens)

                    obj_tokens = [
                        token['lemma'] for token in lemmas[obj_start:obj_end]
                        if token['pos'].startswith('NN')
                    ]
                    l_object = ' '.join(obj_tokens)

                    relation_tokens = [
                        token['lemma'] for token in lemmas[rel_start:rel_end]
                        if token['pos'].startswith('VB')
                    ]
                    l_relation = ' '.join(relation_tokens)

                    if not l_subject or not l_object or not l_relation:
                        continue

                    relationSent = f"{l_subject.strip()} &{l_object.strip()} &{l_relation.strip()}"
                    w.write(relationSent + '\n')
                    num_rel += 1

    except Exception as e:
        log.write(f"[Error] Exception at sentence {cnt}: {sentence}\n")
        log.write(f"         Error message: {str(e)}\n")
w.close()
f.close()
log.close()
nlp.close()
# Out:
# 100%|██████████| 130260/130260 [35:05<00:00, 61.88it/s]

# %%
print('Result written to:', entity_rel_path)
print('Error log written to:', log_path)
print('Total number of processed sentences: ' + str(cnt))
print('Total number of relations extracted: ' + str(num_rel))
# Out:
# Result written to: msrvtt_entity_total.txt
# Error log written to: error_log.txt
# Total number of processed sentences: 130260
# Total number of relations extracted: 53611

# %% [markdown]
# ## Clean entities

# %%
english_vocab = set(words.words())
stop_words = set(stopwords.words('english'))
# akg_vocab = None # replace vocabulary of model
akg_vocab = set()

def load_triples(filepath):
    triples = []
    with open(filepath, 'r') as f:
        for line in f:
            parts = line.strip().split('&')
            if len(parts) == 3:
                head, tail, relation = parts
                triples.append((head.strip(), tail.strip(), relation.strip()))
    return triples

def is_valid_entity(entity):
    tokens = entity.split()
    for token in tokens:
        if token in akg_vocab:
            continue
        if len(token) == 1 or not token.isalpha() or token not in english_vocab:
            return False
    return True

def filter_triples(triples):
    remove_relations = {"be", "have", "do", "get", "can", "is", "are"}
    filtered = []
    for h, r, t in triples:
        if r in remove_relations:
            continue
        if len(h.split()) < 1 or len(t.split()) < 1:
            continue
        if len(h.split()) > 2 or len(t.split()) > 2:
            continue
        if not is_valid_entity(h) or not is_valid_entity(t):
            continue
        filtered.append((h, r, t))
    return filtered

def normalize_triples(triples):
    def normalize_text(text):
        quantifiers = {
            "some", "many", "several", "few", "one", "two", "three", "four", "five", "six", "seven", "eight", "nine", "ten",
            "all", "both", "each", "every", "no", "none", "any", "most", "more", "less"
        }
        quantifiers.update(str(i) for i in range(1, 51))
        text = text.lower()
        text = re.sub(rf"[{string.punctuation}]", "", text)
        tokens = text.strip().split()
        tokens = [w for w in tokens if w not in stop_words.union(quantifiers)]
        return ' '.join(tokens)
    norm_triples = []
    for h, r, t in triples:
        norm_h = normalize_text(h)
        norm_t = normalize_text(t)
        norm_r = normalize_text(r)
        if norm_h and norm_t and norm_r:
            norm_triples.append((norm_h, norm_r, norm_t))
    return norm_triples

triples = load_triples(dataset + "_entity_total.txt")
triples = normalize_triples(triples)
triples = filter_triples(triples)

with open(dataset + "_cleaned_entities.txt", "w") as f:
    for h, t, r in triples:
        relationSent = f"{h} &{t} &{r}"
        f.write(relationSent + '\n')
print('number of triples:', len(triples))

# %% [markdown]
# ## Filter triplets

# %%
# english_vocab = set(words.words())
# stop_words = set(stopwords.words('english'))
# # akg_vocab = None # replace vocabulary of model
# akg_vocab = set()

# def load_triples(filepath):
#     triples = []
#     with open(filepath, 'r') as f:
#         for line in f:
#             parts = line.strip().split('&')
#             if len(parts) == 3:
#                 head, tail, relation = parts
#                 triples.append((head.strip(), tail.strip(), relation.strip()))
#     return triples

# def is_valid_entity(entity):
#     tokens = entity.split()
#     for token in tokens:
#         if token in akg_vocab:
#             continue
#         if len(token) == 1 or not token.isalpha() or token not in english_vocab:
#             return False
#     return True

# def filter_triples(triples):
#     remove_relations = {"be", "have", "do", "get", "can", "is", "are"}
#     filtered = []
#     for h, r, t in triples:
#         if r in remove_relations:
#             continue
#         if len(h.split()) < 1 or len(t.split()) < 1:
#             continue
#         if len(h.split()) > 2 or len(t.split()) > 2:
#             continue
#         if not is_valid_entity(h) or not is_valid_entity(t):
#             continue
#         filtered.append((h, r, t))
#     return filtered

# def normalize_triples(triples):
#     def normalize_text(text):
#         quantifiers = {
#             "some", "many", "several", "few", "one", "two", "three", "four", "five", "six", "seven", "eight", "nine", "ten",
#             "all", "both", "each", "every", "no", "none", "any", "most", "more", "less"
#         }
#         quantifiers.update(str(i) for i in range(1, 51))
#         text = text.lower()
#         text = re.sub(rf"[{string.punctuation}]", "", text)
#         tokens = text.strip().split()
#         tokens = [w for w in tokens if w not in stop_words.union(quantifiers)]
#         return ' '.join(tokens)
#     norm_triples = []
#     for h, r, t in triples:
#         norm_h = normalize_text(h)
#         norm_t = normalize_text(t)
#         norm_r = normalize_text(r)
#         if norm_h and norm_t and norm_r:
#             norm_triples.append((norm_h, norm_r, norm_t))
#     return norm_triples

def deduplicate_triples(triples):
    return list(set(triples))

triples = load_triples(dataset + "_cleaned_entities.txt")
# triples = normalize_triples(triples)
# triples = filter_triples(triples)
triples = deduplicate_triples(triples)

with open(dataset + "_filtered_entities.txt", "w") as f:
    for h, t, r in triples:
        relationSent = f"{h} &{t} &{r}"
        f.write(relationSent + '\n')
print('number of triples:', len(triples))
# Out:
# number of triples: 27931

# %% [markdown]
# ## Build dataset for TransE

# %%
import random
import os

def generate_mappings(triples):
    entity2id, relation2id = {}, {}
    eid, rid = 0, 0
    for h, r, t in triples:
        for ent in [h, t]:
            if ent not in entity2id:
                entity2id[ent] = eid
                eid += 1
        if r not in relation2id:
            relation2id[r] = rid
            rid += 1
    return entity2id, relation2id

def split_data(triples, val_ratio=0.1, test_ratio=0.1):
    random.seed(42)
    random.shuffle(triples)
    n = len(triples)
    test_size = int(n * test_ratio)
    val_size = int(n * val_ratio)
    test_triples = triples[:test_size]
    val_triples = triples[test_size:test_size+val_size]
    train_triples = triples[test_size+val_size:]
    return train_triples, val_triples, test_triples

def write_output(train_triples, val_triples, test_triples, entity2id, relation2id, path):
    files = [
        'train2id.txt',
        'valid2id.txt',
        'test2id.txt',
        'entity2id.txt',
        'relation2id.txt'
    ]

    # Xóa file cũ nếu tồn tại
    for file in files:
        file_path = os.path.join(path, file)
        if os.path.exists(file_path):
            os.remove(file_path)

    # Train
    with open(os.path.join(path, 'train2id.txt'), 'w') as f:
        f.write(f"{len(train_triples)}\n")
        for h, r, t in train_triples:
            f.write(f"{entity2id[h]}\t{entity2id[t]}\t{relation2id[r]}\n")

    # Validation
    with open(os.path.join(path, 'valid2id.txt'), 'w') as f:
        f.write(f"{len(val_triples)}\n")
        for h, r, t in val_triples:
            f.write(f"{entity2id[h]}\t{entity2id[t]}\t{relation2id[r]}\n")

    # Test
    with open(os.path.join(path, 'test2id.txt'), 'w') as f:
        f.write(f"{len(test_triples)}\n")
        for h, r, t in test_triples:
            f.write(f"{entity2id[h]}\t{entity2id[t]}\t{relation2id[r]}\n")

    # Entities
    with open(os.path.join(path, 'entity2id.txt'), 'w') as f:
        f.write(f"{len(entity2id)}\n")
        for e, i in entity2id.items():
            f.write(f"{e}\t{i}\n")

    # Relations
    with open(os.path.join(path, 'relation2id.txt'), 'w') as f:
        f.write(f"{len(relation2id)}\n")
        for r, i in relation2id.items():
            f.write(f"{r}\t{i}\n")

entity2id, relation2id = generate_mappings(triples)
train_triples, val_triples, test_triples = split_data(triples)

print(f"Number of entities: {len(entity2id)}")
print(f"Number of relations: {len(relation2id)}")
print(f"Train triples: {len(train_triples)}")
print(f"Validation triples: {len(val_triples)}")
print(f"Test triples: {len(test_triples)}")

os.makedirs(f"./benchmarks/{dataset}", exist_ok=True)
write_output(train_triples, val_triples, test_triples, entity2id, relation2id, path=f"./benchmarks/{dataset}")
# Out:
# Number of entities: 3518
# Number of relations: 11608
# Train triples: 22345
# Validation triples: 2793
# Test triples: 2793
